# %% [markdown]
# # 05b - Snapshot Reproducibility for Training

# %%
import json, time
from src.bench.iceberg_utils import spark_iceberg, read_snapshot, table_snapshots

RUN_MANIFEST = 'experiments/run_manifest.json'
print('Tie each training run to an Iceberg snapshot-id and log metrics here.')
# TODO: after training, append {snapshot_id, git_sha, metrics} to RUN_MANIFEST
