# %% [markdown]
# # 02b - Iceberg Experiments: Planning, Compaction & Throughput

# %%
from src.bench.iceberg_utils import spark_iceberg, read_snapshot, table_snapshots
from pyspark.sql import functions as F
import time, pandas as pd

print('Configure your catalog via configs/iceberg.conf or Spark submit properties-file.')
# TODO: build spark with iceberg and run scans on small-file tables, then compact and remeasure.
