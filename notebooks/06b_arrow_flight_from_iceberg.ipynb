# %% [markdown]
# # 06b - Arrow Flight from Iceberg Snapshot

# %%
print('Prototype: Spark reads Iceberg -> Arrow Flight server; client streams to GPU training.')
# TODO: Add Flight producer/consumer once environment is ready.
